# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
X1 = [1,3,6,8]
Y1 = [3,6,4,8]

# %%
#line graph
plt.plot(X1,Y1)
plt.xlabel('X1')
plt.ylabel('Y1')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
X2 = [3,6,4,8]
Y2 = [1,3,6,3]

# %%
plt.plot([X1,X2],[Y1,Y2])
#plt.plot(X2,Y2)
plt.xlabel('X1')
plt.ylabel('Y1')
plt.legend([])
plt.show()

# %%
plt.plot(X1,Y1,label='line1')
plt.plot(X2,Y2,label='line2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sample')
plt.legend()
plt.show()

# %%
plt.plot(X1,Y1,label='line1')
plt.plot(X2,Y2,label='line2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sample')
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(X1,Y1,color='Red',linewidth=3,linestyle='-')
plt.plot(X2,Y2,color='orange',linewidth=3,linestyle='-.')
plt.show()

# %%
plt.plot(X1,Y1,label='line1',color='red',marker='o',markersize=5)
plt.plot(X2,Y2,label='line2',color='orange',marker='s',markersize=5)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sample')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.arange(0,40,0.0002)
a = np.sin(c)
b= np.cos(c)

# %%
a
# Out:
# array([  0.00000000e+00,   1.99999999e-04,   3.99999989e-04, ...,
#          7.45513189e-01,   7.45379876e-01,   7.45246533e-01])

# %%
plt.plot(c,a)
plt.plot(c,b)
plt.show()

# %%
x =list('abcdefghi')
y= [1,2,3,4,5,6,7,8,9]
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-ac5b27574687> in <module>()
#       1 x =list('abcdefghi')
#       2 y= [1,2,3,4,5,6,7,8,9]
# ----> 3 plt.plot(x,y)
#       4 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# ...

# %%
#barplot
x = [3,5,7,9]
y = [8,12,15,11]
plt.bar(x,y,label='Data1')
plt.bar(y,x,label='Data2')
plt.legend()
plt.show()

# %%
x = [3,5,7,9]
y = [8,12,15,11]
plt.barh(x,y,label='Data1')
plt.barh(y,x,label='Data2')
plt.legend()
plt.show()

# %%
df = pd.DataFrame({'Revenue':[780,800,930,700,1100]},index=['TCS','Wipro','Infosys','Google','Facebook'])

# %%
df

# %%
plt.bar(df.index,df['Revenue'])
plt.xticks(rotation=180)
plt.show()

# %%
#Scatter plot
plt.scatter([1,2,3,4],[2,4,6,8],label='Data1')
plt.scatter([3,5,7,2],[1,3,6,8],label='Data2')
plt.legend()
plt.show()

# %%
#histogram
bsm = [113,85,90,115,149,88,93,115,135,80,77,82,129]
plt.hist(bsm)
plt.show()
plt.hist(bsm,bins=3)
plt.show()
plt.hist(bsm,bins=3,rwidth=0.9)
plt.show()

plt.hist(bsm,bins=[75,95,125,150],rwidth=0.9)
plt.show()

# %%
bsf=[67,98,89,120,133,150,84,69,89,79,120,112,100]
plt.hist([bsm,bsf],bins=[75,95,125,150],rwidth=0.9,color=['pink','orange'],label=['Male','Female'])
plt.legend()
plt.show()

# %%
#seaborn
import warnings
set_warnings = False
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
dataframe = sns.load_dataset('tips')
dataframe.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dataframe.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.0 KB

# %%
dataframe.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
dataframe['day'].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
dataframe['time'].unique()
# Out:
# [Dinner, Lunch]
# Categories (2, object): [Dinner, Lunch]

# %%
dataframe[dataframe['time']=='Dinner'].head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.lmplot(x='total_bill',y='tip',data=dataframe,fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',hue='day',data=dataframe,fit_reg=False)
plt.show()

# %%
dataframe[dataframe['tip']==max(dataframe['tip'])]

# %%
dataframe[dataframe['tip']==min(dataframe['tip'])]

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',data=dataframe,fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',palette='ocean',markers=['o','x'],data=dataframe,fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',row='smoker',data=dataframe,fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',col='smoker',data=dataframe,fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',col='time',row='smoker',data=dataframe,fit_reg=False)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',col='size',row='day',data=dataframe,fit_reg=False)
plt.show()

# %%
sns.stripplot(x='day',y='total_bill',data=dataframe,jitter=False)
plt.show()

# %%
sns.swarmplot(x='day',y='total_bill',data=dataframe)

# %%
print('{}'.format(len(dataframe[dataframe['sex']=='Male'])))
# Out:
# 157

# %%
len(dataframe[dataframe['sex']=='Female'])
# Out:
# 87

# %%
dataframe['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.countplot(x='sex',data=dataframe)

# %%
sns.countplot(x='smoker',data=dataframe)

# %%
sns.countplot(x='size',data=dataframe)

# %%
sns.countplot(x='sex',hue='smoker',data=dataframe)

# %%
sns.jointplot(x='total_bill',y='tip',data=dataframe)
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=dataframe,kind='kde')
plt.show()

# %%
sns.boxplot(x='total_bill',data=dataframe,whis=False)
plt.plot()

# %%
sns.boxplot(y='total_bill',x='day',data=dataframe)
plt.plot()

# %%
sns.distplot(dataframe['total_bill'])
plt.show()

# %%
sns.distplot(a['total_bill'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-ad973204c623> in <module>()
# ----> 1 sns.distplot(a['total_bill'])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
a['total_bill'].skew()

# %%
dataframe['total_bill'].skew()
# Out:
# 1.1332130376158205

# %%
dataframe['total_bill'].kurtosis()
# Out:
# 1.2184840156638854

# %%
sns.distplot(dataframe['total_bill'],kde=False)
plt.show()

# %%
dataframe.quantile(.9)
# Out:
# total_bill    32.235
# tip            5.000
# size           4.000
# Name: 0.9, dtype: float64

# %%
dataframe.quantile(.99)
# Out:
# total_bill    48.2270
# tip            7.2145
# size           6.0000
# Name: 0.99, dtype: float64

# %%
iqr = dataframe['total_bill'].quantile(.75) - dataframe['total_bill'].quantile(.25)
b1 = dataframe['total_bill'].quantile(.25)-(1.5*iqr)
b2 = dataframe['total_bill'].quantile(.75)+(1.5*iqr)

# %%
b1
# Out:
# -2.8224999999999945

# %%
iqr*1.5
# Out:
# 16.169999999999995

# %%
dataframe['total_bill'].quantile(.75)
# Out:
# 24.127499999999998

# %%
b2

# %%
a = dataframe[dataframe['total_bill']>b1]

# %%
a = a[a['total_bill']<b2]

# %%
sns.boxplot(a['total_bill'])
plt.show()

# %%
from scipy.stats import  zscore

# %%
z = zscore(a.total_bill)
z
# Out:
# array([ -3.14711305e-01,  -1.06323531e+00,   1.37779900e-01,
#          4.38315103e-01,   5.40744704e-01,   6.19536705e-01,
#         -1.23995452e+00,   7.98507107e-01,  -5.34203307e-01,
#         -5.63468908e-01,  -1.07111451e+00,   1.74175992e+00,
#         -4.91430507e-01,  -1.52624903e-01,  -5.57840908e-01,
#          2.01939101e-01,  -1.06436091e+00,  -3.93503306e-01,
#         -3.16962505e-01,   9.72582994e-02,  -2.10030504e-01,
#          5.67366990e-02,  -4.52034507e-01,   2.21000952e+00,
#          3.83349840e-03,  -2.22412104e-01,  -7.22178510e-01,
#         -7.98719310e-01,   2.15446301e-01,  -1.53017018e-02,
#         -1.15215771e+00,  -1.61629703e-01,  -5.31952107e-01,
#          1.01760699e-01,  -2.25788904e-01,   4.81087904e-01,
#         -3.91252106e-01,  -3.21464905e-01,  -1.23359303e-01,
#          1.29264551e+00,  -4.21643306e-01,  -2.61808105e-01,
#         -6.58019309e-01,  -1.13752491e+00,   1.19471831e+00,
# ...

# %%
dataframe['zscore'] = zscore(dataframe['total_bill'])

# %%
dataframe.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size    zscore
# 0       16.99  1.01  Female     No  Sun  Dinner     2 -0.314711
# 1       10.34  1.66    Male     No  Sun  Dinner     3 -1.063235
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.137780
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.438315
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.540745

# %%
d=dataframe[abs(dataframe['zscore'])<3]
d
# Out:
#      total_bill   tip     sex smoker   day    time  size    zscore
# 0         16.99  1.01  Female     No   Sun  Dinner     2 -0.314711
# 1         10.34  1.66    Male     No   Sun  Dinner     3 -1.063235
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.137780
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.438315
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.540745
# 5         25.29  4.71    Male     No   Sun  Dinner     4  0.619537
# 6          8.77  2.00    Male     No   Sun  Dinner     2 -1.239955
# 7         26.88  3.12    Male     No   Sun  Dinner     4  0.798507
# 8         15.04  1.96    Male     No   Sun  Dinner     2 -0.534203
# 9         14.78  3.23    Male     No   Sun  Dinner     2 -0.563469
# 10        10.27  1.71    Male     No   Sun  Dinner     2 -1.071115
# 11        35.26  5.00  Female     No   Sun  Dinner     4  1.741760
# 12        15.42  1.57    Male     No   Sun  Dinner     2 -0.491431
# ...

# %%
sns.boxplot(d['total_bill'])
plt.show()

# %%
dataframe[dataframe['total_bill'] in range(b1,b2)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-73aee74f6447> in <module>()
# ----> 1 dataframe[dataframe['total_bill'] in range(b1,b2)]
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
dataframe.groupby('day')
dataframe
# Out:
#      total_bill   tip     sex smoker   day    time  size    zscore
# 0         16.99  1.01  Female     No   Sun  Dinner     2 -0.314711
# 1         10.34  1.66    Male     No   Sun  Dinner     3 -1.063235
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.137780
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.438315
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.540745
# 5         25.29  4.71    Male     No   Sun  Dinner     4  0.619537
# 6          8.77  2.00    Male     No   Sun  Dinner     2 -1.239955
# 7         26.88  3.12    Male     No   Sun  Dinner     4  0.798507
# 8         15.04  1.96    Male     No   Sun  Dinner     2 -0.534203
# 9         14.78  3.23    Male     No   Sun  Dinner     2 -0.563469
# 10        10.27  1.71    Male     No   Sun  Dinner     2 -1.071115
# 11        35.26  5.00  Female     No   Sun  Dinner     4  1.741760
# 12        15.42  1.57    Male     No   Sun  Dinner     2 -0.491431
# ...

# %%
dataframe.groupby('day').mean().drop('zscore',axis=1)

# %%
dataframe.groupby('time').count()
# Out:
#         total_bill  tip  sex  smoker  day  size  zscore
# time
# Lunch           68   68   68      68   68    68      68
# Dinner         176  176  176     176  176   176     176

# %%
dataframe.groupby('sex').count()

# %%
dataframe['tip'].groupby(dataframe.smoker).mean()
# Out:
# smoker
# Yes    3.008710
# No     2.991854
# Name: tip, dtype: float64

# %%
dataframe['tip'].groupby([dataframe.smoker,dataframe.sex]).mean()
# Out:
# smoker  sex
# Yes     Male      3.051167
#         Female    2.931515
# No      Male      3.113402
#         Female    2.773519
# Name: tip, dtype: float64

# %%
def f(x):
    return pd.Series(dict(size = x['total_bill'].count(),
                       smoker = x['tip'].mean()
                       ))

# %%
dataframe.groupby([dataframe.time,dataframe.sex]).apply(f)
# Out:
#                 size    smoker
# time   sex
# Lunch  Male     33.0  2.882121
#        Female   35.0  2.582857
# Dinner Male    124.0  3.144839
#        Female   52.0  3.002115

# %%
sns.factorplot("time","size",data=dataframe,hue="size");

# %%
sns.factorplot("smoker","size",data=dataframe,hue="size");
